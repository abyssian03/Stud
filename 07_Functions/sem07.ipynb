# %% [markdown]
# #### Задача 1.
#
# Напишите функцию, которая принимает два целых числа a и b и возвращает результат возведения в степень a ** b, только оператором ** пользоваться нельзя, нужно сделать это в цикле!

# %%
# your code here

# %% [markdown]
# #### Задача 2.
#
# Напишите функцию, которая будет принимать слово и проверять, состоит ли оно только из кириллических букв. Функция должна возвращать объект bool (True/False).

# %%
# your code here

# %% [markdown]
# #### Задача 3.
#
# Напишите функцию для подсчета букв в слове: пользователь вводит какую-то строку, а функция должна в форматированном виде вывести, сколько раз встретилась та или иная буква.
#
# **Пример:**
#
# *Ввод:* 'ABBYY'
#
# *Вывод:*
#
# 'A': 1
#
# 'B': 2
#
# 'Y': 2

# %%
# your code here

# %% [markdown]
# #### Задача 4.
#
# Напишите функцию sign, которая принимает целое число и возвращает True, если оно положительное, и False, если оно отрицательное. На 0 можно возвращать NoneType (подумайте, как это сделать?)

# %%
# your code here

# %% [markdown]
# #### Задача 5.
#
# Напишите функцию, которая принимает два числа k и b и возвращает другую функцию, которая вычисляет результат уравнения k * x + b (х - ее аргумент).

# %%
# your code here

# %% [markdown]
# #### Задача 6.
#
# Напишите функцию, которая принимает два аргумента и производит одну из операций над ними - конкатенацию, если оба аргумента являются упорядоченными коллекциями (строка, список или кортеж), умножение, если один из аргументов является упорядоченной коллекцией, а другой целым числом (причем неважно, в каком порядке они передаются), и возведение в степень, если оба аргумента являются числом. Если ни одни из этих условий не выполняется, пусть функция возвращает сообщение "Bad args". Аргументы создайте в коде в виде констант так, чтобы можно было проверить каждый из вариантов, и выведите результаты соответствующего количества вызовов функции в формате <список аргументов, переданных в функцию> : <результат работы функции на этом списке аргументов>.

# %%
def operation_executor(x, y)

# your code here

# %% [markdown]
# #### Задача 7.
#
# Перепишите код к предыдущей задаче  так, чтобы каждая операция задавалась в виде отдельной функции, а основная функция принимала три аргумента -- два тех же, что и раньше, плюс один аргумент, указывающий, какую операцию мы хотим произвести над этими аргументами. Проверку на соответствие типов данных каждой из операций поместите внутрь самих операций и при несоответствии выводите дифференцированные сообщения.
#
# **Пример:**
#
#         result = operation_executor("Вася", 3, exponentiate)
#
#         >>>> Bad args: Exponentiation is only available for two numeric arguments!

# %%
def operation_executor(x, y, func)

# your code here

# %% [markdown]
# #### Задача 8 (*) - элементы функционального программирования
#
# Дан список словарей. Получите список только имен из всех словарей списка, используя map и lambda.

# %%
users = [{"name": "Anna", "age": 20}, {"name": "Boris", "age": 25}, {"name": "Clara", "age": 30}]

# your code here
