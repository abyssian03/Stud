# %% [markdown]
# #### Задача 1.
#
# Дано трехзначное число. Нужно узнать, есть ли в нем хотя бы одна цифра 7. Если такая цифра есть, выведите на экран "Удача!", в ином случае "Неудача". Используйте условную конструкцию.
#
# **Подсказка:** Алгоритм выделения цифр трехзначного числа можно списать из текста второй лекции.

# %%
# your code here

# %% [markdown]
# #### Задача 2.
#
# Напишите простой калькулятор. Пользователь вводит два числа (целых или дробных) и символ операции (+, -, *, /). Программа должна вывести результат вычисления. Если пользователь ввел /, а второе число равно 0, программа должна вывести «Ошибка: деление на ноль!».
#
# **Примечание:** Символы операций обрабатываются питоном точно так же, как буквы.

# %%
# your code here

# %% [markdown]
# #### Задача 3.
# Запросите у пользователя произвольный символ (т.е. строку единичной длины). Если строка состоит из заглавной буквы латинского алфавита (A-Z), напишите "Is upper". Если строка состоит из строчной латинской буквы (a-z), напишите "Is lower". В ином случае ничего не пишите. Гарантируется, что пользователь введет именно один символ.
#
# **Подсказка:** Используйте операции сравнения строк и имейте в виду, что коды букв расположены подряд, в алфавитном порядке.

# %%
# your code here

# %% [markdown]
# #### Задача 4.
#
# Даны строны треугольника. Нужно выбрать, какое из сообщений подходит, и вывести его (используйте теорему Пифагора):
#
# "Треугольник прямоугольный"
#
# "Треугольник тупоугольный"
#
# "Треугольник остроугольный"

# %%
# your code here

# %% [markdown]
# #### Задача 5.
#
# Точки А, В, С расположены на одной прямой в том порядке, в котором они написаны (т.е. точка В расположена между точками А и С). Из точки В в точку С со скоростью v едет велосипедист, а из точки А со скоростью u его догоняет мотоциклист. Напишите программу, которая запрашивает у пользователя расстояния АВ и ВС, скорости v и u, а в качестве ответа выдает "Да", если мотоциклист догонит велосипедиста до того, пока тот не достиг точки С, и "Нет" в противном случае.

# %%
# your code here

# %% [markdown]
# #### Задача 6 (*) - на логику.
#
# Кащей Бессмертный поймал Ивана Царевича и говорит ему: ты должен отгадать зададку. Если угадаешь правильно, получишь Василису Прекрасную и уйдешь с ней невредимым. Если не угадаешь, умрешь.
#
# Загадка такая. В комнате есть четыре двери, распольженные по порядку номеров (от 1 до 4). За одной из них Василиса, за тремя остальными головы Змея Горыныча, по одной на каждую дверь. Ты можешь заранее выбрать один номер двери, и я скажу тебе, что за ней. Если после этого ты все еще не будешь знать, где Василиса, то снова можешь выбрать один номер двери, и я скажу тебе, находится ли Василиса по соседству с этой дверью. Если и после этого ты не будешь знать, где Василиса, то я скажу тебе, находится ли она за дверью с четным номером или с нечетным. Затем ты должен, ничего не спрашивая больше, войти в одну из дверей и принять свою судьбу.
#
# Вам нужно написать программу, которая предлагает пользователю загадать число от 1 до 4 (только в уме, не вводить его!), а затем задает ему вопросы в соответствии с условием Кащея. Не более чем за три вопроса ваша программа должна однозначно определить, какое число было загадано, и выдать его на экран.

# %%
# your code here
