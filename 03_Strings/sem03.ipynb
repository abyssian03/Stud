# %% [markdown]
# #### Задача 1.
#
# Дана строка. Разрежьте ее на две равные части (если длина строки — четная, а если длина строки нечетная, то длина первой части должна быть на один символ больше). Переставьте эти две части местами, результат запишите в новую строку и выведите на экран.

# %%
# your code here

# %% [markdown]
# #### Задача 2.
#
# Программа считывает с клавиатуры какой-нибудь довольно большой текст (пару предложений) и должна посчитать, сколько раз в этом тексте встретился союз "и" (считаем, что вокруг союза обязательно есть по пробелу: " и ").
#
# **Примечание**: Помните, что предложение может начинаться с союза.

# %%
# your code here

# %% [markdown]
# #### Задача 3.
#
# Дана строка, состоящая ровно из двух слов, разделенных пробелом. Переставьте эти слова местами. Результат запишите в строку и выведите получившуюся строку.

# %%
# your code here

# %% [markdown]
# #### Задача 4.
#
# Дана строка. Если в этой строке буква f встречается только один раз, выведите её индекс. Если она встречается два и более раз, выведите индекс её первого и последнего появления. Если буква f в данной строке не встречается, ничего не выводите.

# %%
# your code here

# %% [markdown]
# #### Задача 5.
#
# Дана строка, в которой буква h встречается минимум два раза. Удалите из этой строки первое и последнее вхождение буквы h, а также все символы, находящиеся между ними.
#
# Например, для строки "In the hole in the ground there lived a hobbit" результатом должно стать "In tobbit".

# %%
# your code here

# %% [markdown]
# #### Задача 6.
#
# Дана строка. Замените в этой строке все появления буквы h на букву H, кроме первого и последнего вхождения.

# %%
# your code here

# %% [markdown]
# Задача 7 (*) - на самостоятельность.
#
# Разберитесь, как работает итерация строк, и с ее помощью напишите программу, которая будет запрашивать у пользователя имя и выводить его перевернутым. Гуглите и экспериментируйте, если что-то непонятно, спрашивайте у преподавателя.
#
# **Пример**: Аня -> Яна

# %%
# your code here

# %% [markdown]
# #### Задача 7 (**) - лингвистическая шутка.
#
# Напишите программу, которая будет запрашивать у пользователя любое слово и возвращать его дурацкий искаженный вариант.
#
# **Примеры**: молоко -> шмолоко; весело -> шмесело; привет -> шмивет.
#
# **Подсказка**: Можете завести отдельную служебную строку из одних гласных букв и с ее помощью создавать срезы начиная с первой гласной буквы.

# %%
# your code here
