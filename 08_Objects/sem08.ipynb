# %% [markdown]
# #### Задача 1.
#
# Напишите программу, которая задает класс кошек с одним атрибутом - кличкой, а затем создает объект этого класса с именем "Мурка". Выведите на экран значение атрибута кличка для этого объекта.

# %%
# your code here

# %% [markdown]
# #### Задача 2.
#
# Дополните код из предыдущего задания: создайте у класса кошек метод - мурлыкание. При вызове этого метода пусть печатается "Мррр". Вызовите созданный метод у объекта класса.

# %%
# your code here

# %% [markdown]
# #### Задача 3.
#
# Дополните код из предыдущего задания: задайте у класса кошек подкласс сиамских кошек с дополнительным атрибутом - цветом глаз, который по умолчанию пусть имеет значение "голубой". Создайте объект этого класса, атрибуты которого пусть пользователь введет с клавиатуры.

# %%
# your code here

# %% [markdown]
# #### Задача 4.
#
# Дополните код из предыдущего задания: выведите класс созданного вами объекта с помощью type(). Затем запросите подтверждение того, что этот объект принадлежит родительскому классу кошек.

# %%
# your code here

# %% [markdown]
# #### Задача 5.
#
# Дополните код из предыдущего задания: создайте вторую сиамскую кошку и напишите функцию fight, которая будет принимать на вход два объекта класса кошек и проверять принадлежность их к сиамским. Если обе кошки сиамские, то пусть функция выводит через запятую их клички, а затем сообщение "Хорошая драка!" Если только одна из кошек сиамская, то пусть функция выводит кличку второй (не сиамской) кошки, а затем сообщение "покидает поле боя", и удаляет объект. Подумайте, как надо дополнить класс кошек, чтобы сообщение об удалении проигравшей в драке кошки вызывалось не самой функцией, а методом этого класса. Если обе кошки не сиамские, пусть функция выводит сообщение "Драки нет, мир да любовь.", и больше ничего не делает.

# %%
# your code here

# %% [markdown]
# #### Задача 6.
#
# Дополните код из предыдущего задания: создайте словарь, ключами в котором будут пары кошек, а значениями -- результаты работы функции fight на этих парах. Выведите полученный словарь в порядке возрастания количества сиамских кошек, участвующих в драке.

# %%
# your code here

# %% [markdown]
# #### Задача 7.
#
# Задайте теперь базовый класс собак. Пусть атрибутами собак будут кличка и размер (крупный, средний, мелкий). Методом класса собак пусть будет рост: при вызове этого метода мелкая собака пусть превращается в среднюю, а средняя в крупную. Создайте несколько объектов этого класса, выведите их атрибуты на экран, затем вызовите у них этот метод и снова выведите их атрибуты.

# %%
# your code here

# %% [markdown]
# #### Задача 8 (*) - инкапсуляция
#
# Дополните код из предыдущего задания: инкапсулируйте атрибут размера так, чтобы он мог изменяться только с помощью метода роста. После этого попробуйте вручную изменить атрибут размера и посмотрите, что будет.

# %%
# your code here

# %% [markdown]
# #### Задача 9 (**) - декорирование
#
# Создайте декоратор для класса собак, который будет изменять метод роста так, чтобы при каждом изменении атрибута размера метод выводил сообщение "Собака выросла!", а затем кличку собаки и ее новый размер.

# %%
# your code here
