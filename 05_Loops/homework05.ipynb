# %% [markdown]
# #### Задача 1.
#
# Напишите программу, переводящую трехзначное число из арабской записи в римскую. Срезами и методами строк пользоваться нельзя, работайте с числом как с int.

# %%
# your code here

# %% [markdown]
# #### Задача 2.
#
# Пользователь вводит два положительных четырехзначных числа. Программа должна определить, сколько чисел в диапазоне между этими числами (включая сами эти числа) содержит минимум три одинаковых цифры.

# %%
# your code here

# %% [markdown]
# #### Задача 3.
#
# Пользователь вводит оценки студента по 9 предметам. Требуется найти средний взвешенный балл студента за сессию, с точностью до двух знаков после занятой, если известно, что вес оценки по предмету с номером *n* в списке равен 1/(*n*+1)
#
# **Примечание**: Среднее взвешенное рассчитывается как сумма произведений введенных значений на их веса, деленная на общую сумму весов.

# %%
# your code here

# %% [markdown]
# #### Задача 4.
#
# Напишите программу, которая определяет, является ли последовательность цифр введенного числа возрастающей при просмотре слева направо. Срезами и методами строк пользоваться нельзя, работайте с числом как с int.

# %%
# your code here

# %% [markdown]
# #### Задача 5
#
# Требуется найти наибольший общий делитель двух заданных натуральных чисел, используя алгоритм Евклида.
#
# **Примечание**: Наибольший общий делитель (НОД) пары чисел — это наибольшее число, на которое делятся оба заданных числа.
#
# Для нахождения наибольшего общего делителя двух чисел по алгоритму Евклида нужно заменить большее из чисел на остаток от деления его на меньшее и для полученной пары повторять эту процедуру, пока одно из чисел не станет равно нулю. Тогда второе число будет равно наибольшему общему делителю исходных чисел.
#
# **Пример:** Найти НОД(210, 45)
#
# 1. 210 = 45 х 4 + 30 -- остаток 30.
#
# 2. 45 = 30 х 1 + 15 -- остаток 15.
#
# 3. 30 = 15 х 2 -- остаток 0.
#
# 4. Деление окончено, НОД (210, 45) = 15.

# %%
# your code here

# %% [markdown]
# #### Задача 6
#
# Пользователь в цикле вводит сочетание двух слов. Если оба слова начинаются на согласные, программа должна поменять местами их части до первой гласной и вывести получившееся словосочетание. Если одно или оба слова начинаются на гласные, то программа должна поменять местами части слов до буквы, следующей за первой гласной. Концом ввода считается словосочетание, в котором есть хотя бы одно слово, не содержащее гласных букв.
#
# **Примеры:** плоды трудов -> троды плудов; Омар Хаям -> Хамар Оям

# %%
# your code here

# %% [markdown]
# #### Задача 7 (*) - программист воскрес из мертвых
#
# В некотором языке действуют следующие правила:
#
#
# Предложение состоит ровно из трёх слов: ПРИЛАГАТЕЛЬНОЕ, СУЩЕСТВИТЕЛЬНОЕ, ГЛАГОЛ (именно в этом порядке).
#
# Прилагательное может быть одним из: *быстрый, ленивый, красивый, голодный*.
#
# Существительное может быть одним из: *кот, пёс, бык, конь*.
#
# Глагол может быть одним из: *спит, бежит, ест, лежит*.
#
#
# Также есть четыре правила сочетаемости:
#
# 1. Если глагол "бежит", то прилагательное не может быть "ленивый".
# 2. Если прилагательное "голодный", то глагол должен быть "ест".
# 3. Если  существительное "пёс", то глагол не может быть "спит".
# 4. Если прилагательное "быстрый", то существительное не может быть "бык".
#
#
# Программа принимает на вход любое из слов данного языка и должна вывести все возможные корректные предложения с этим словом (составляйте их именно в коде, не вручную).
#
# **Подсказка**: Решайте перебором со вложенными циклами либо используйте модуль itertools, кто знает, что это такое.

# %%
# your code here

# %% [markdown]
# #### Задача 8 (**) - шифр Цезаря
#
# Напишите программу, которая сдвигает буквы в строке на *n* позиций вперед по алфавиту. Сдвиг циклический, т.е. если если достигнута последняя буква алфавита, то следующей будет первая буква, потом вторая и т.д. Пробелы и знаки препинания символами алфавита не считаются. Строка и число *n* вводятся пользователем. Регистр букв не имеет значения.

# %%
# your code here
