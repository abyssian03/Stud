# %% [markdown]
# #### Задача 1.
#
# Нужно вывести таблицу умножения: на первой строчке выводятся 1 2 3 4 5 6 7 8 9, на второй 2 4 6 8 ...  и так далее.
#
# **Усложнение**: попробуйте подогнать вывод так, чтобы получалась ровная сетка.

# %%
# your code here

# %% [markdown]
# #### Задача 2.
#
# Классическая задача! Нарисуйте ёлочку из символов \* высотой n ярусов (число n вводится пользователем). Ёлочка должна быть симметричной, и между каждыми двумя \* должно быть по пробелу. См. пример для n == 3.
#
#           *
#          * *
#         * * *

# %%
# your code here

# %% [markdown]
# #### Задача 3.
#
# Пользователь в строчку вводит доход фирмы за каждый день недели, с понедельника по субботу. Вам нужно
#
# 1. Оценить динамику: есть ли устойчивый тренд на рост или падение дохода в течение всей недели?
# 2. Найти день с максимальным и день с минимальным доходом.
# 3. Посчитать средний дневной доход фирмы.
#
# Используйте цикл for.

# %% [markdown]
# #### Задача 4.
#
# Пользователь вводит какие-то строки, которые наша программа должна приводить в "заголовочный" вид: все слова в строке с заглавной буквы. Когда пользователь вводит "стоп", программа должна завершить работу, причем ей неважно, в каком регистре введен "стоп", хоть заборчиком.

# %%
# your code here

# %% [markdown]
# #### Задача 5.
#
# Пользователь вводит целое число, в котором заранее мы не знаем, сколько цифр. Программа должна вернуть произведение цифр этого числа.

# %%
# your code here

# %% [markdown]
# #### Задача 6.
#
# Пользователь вводит сколько-то целых чисел, положительные и отрицательные вперемешку. Программа должна вывести самое большое из введенных чисел, имеющих в последнем знаке 0. Само число 0 считается концом ввода и в сравнении не участвует. Если ни одного положительного или отрицательного числа с нулем в последнем знаке не было, программа должна вывести соответствующее сообщение. Списками, кортежами, множествами пользоваться нельзя.

# %%
# your code here

# %% [markdown]
# #### Задача 7.
#
# Напишем программу для проверки подобранных рифм: пользователь в цикле вводит два слова, программа должна проверить, что у них совпадает не меньше четырех последних букв (будем наивно считать, что все читается, как пишется). Цикл останавливается, если первое из введенных слов не содержит букв.

# %%
# your code here
