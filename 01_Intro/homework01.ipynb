# %% [markdown]
# #### Задача 1.
#
# Ваши баллы за семестр будут начисляться в следующем виде: берется доля выполненных домашних заданий (то, что сделали вы / сколько всего можно было сделать), а также доля выполненных семинарских задачек. Первое составляет 60% от всех баллов, второе, соответственно, 40%. Напишите программу, которая будет запрашивать четыре цифры:
#
# - сколько всего баллов можно было заработать за домашки
#
# - сколько баллов за домашки заработал студент
#
# - сколько всего баллов можно было заработать за семинары
#
# - сколько баллов за семинары заработал студент
#
# Программа должна вычислить заработанные баллы.

# %%
# your code here

# %% [markdown]
# #### Задача 2.
#
# Пользователь вводит число (int). Если число четное, разделите его целочисленным делением на 4. Если число нечетное, верните остаток от деления. Результат выведите на экран.

# %%
# your code here

# %% [markdown]
# #### Задача 3.
#
# Напишите программу, которая принимает на вход число секунд и возвращает ответ в часах, минутах и секундах в виде 12:13:14.
#
# **Подсказка:** можно использовать остаток от деления и целочисленное деление, а также параметр end функции print().

# %%
# your code here

# %% [markdown]
# #### Задача 4.
#
# Напишите программу, которая переводит вес из килограммов в фунты. (Вес вводится пользователем).

# %%
# your code here

# %% [markdown]
# #### Задача 5.
#
# Дано положительное действительное число X. Выведите его первую цифру после десятичной точки.

# %%
# your code here
