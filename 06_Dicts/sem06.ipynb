# %% [markdown]
# #### Задача 1.
#
# Собираем телефонный справочник. Пользователь в бесконечном цикле вводит фамилию и номер телефона через пробел, пока не введет "хватит". Программа должна завести словарь, в котором по фамилии хранится номер телефона, и вывести его на экран.

# %%
# your code here

# %% [markdown]
# #### Задача 2.
#
# У нас есть два списка: в одном по порядку записаны имена людей, а в другом их дни рождения (формат неважен, можно в строках). Нам нужно объединить два списка в словарь, где ключ - имя, а значение - день рождения, причем мы знаем, что дни рождения в том же порядке, что и имена людей. После этого пусть программа запросит у пользователя имя человека и выдаст ему день рождения этого человека, либо сообщение "Запись отсутствует", если такого человека нет в словаре.

# %%
# your code here

# %% [markdown]
# #### Задача 3.
#
# Вводится текст. Нам нужно посчитать относительные частоты всех его слов: то есть, частоты слов нужно дополнительно поделить на общее их количество. В результате программа должна выдать словарь, где слово является ключом, а его частота - значением. Для выдачи используйте метод .items()

# %%
# your code here

# %% [markdown]
# #### Задача 4.
#
# Даны два словаря, и известно, что в них могут встречаться записи со значением None. Нужно объединить их, но так, чтобы в результирующий словарь из двух записей с одинаковыми ключами и разными значениями попала та, значение которой отлично от None. Если обе записи отличны от None, выбор между ними произволен. Полученный результат выведите на экран.

# %%
# your code here

# %% [markdown]
# #### Задача 5
#
# Превратим англо-русский словарь в русско-английский. В исходном англо-русском словаре для одного английского слова могут идти в алфавитном порядке русские варианты перевода:
#
#     'call': ['звать', 'звонить', 'называть']
#
# Может быть и такая ситуация, что одно и то же русское слово встречается в переводах двух английских слов:
#
#     'name': ['имя', 'называть']
#
# Наш русско-английский словарь должен правильно перевернуться: не потерять ни одного перевода, при этом английские переводы тоже должны быть в алфавитном порядке. Программа должна вывести новый словарь на экран, причем русские слова должны быть отсортированы, как и их переводы.

# %%
# your code here

# %% [markdown]
# #### Задача 6
#
# Дан словарь. Распакуйте из него ТОЛЬКО ЗНАЧЕНИЯ, запишите первые три значения в три переменных с именами first, second и third, а остальные значения запакуйте в список. Полученные данные (три переменных и список) выведите на экран.

# %%
# your code here

# %% [markdown]
# #### Задача 7 (*) - имитация работы с БД
#
# Дана таблица с данными о корпусе текстов, метаинформацией и частотностью слов в них. Нужно написать код, который:
#
# 1. Находит все тексты, написанные в XIX веке (1800–1899)
# 2. Считает реднее количество уникальных слов на текст
# 3. Определает слово, которое чаще всего встречается в пьесах
# 4. Составляет словарь количества текстов каждого жанра:
#
#         ({"роман": 2, "пьеса": 2, ...})

# %%
# Данные корпуса (симулируем результат SQL-запроса)
corpus = [
    {
        "id": 1,
        "title": "Война и мир. Том 1",
        "author": "Толстой Л.Н.",
        "year": 1869,
        "genre": "роман",
        "tokens": 320000,
        "unique_words": 12500,
        "top_words": {"и": 15000, "в": 12000, "не": 8000, "что": 6000, "он": 5500}
    },
    {
        "id": 2,
        "title": "Преступление и наказание",
        "author": "Достоевский Ф.М.",
        "year": 1866,
        "genre": "роман",
        "tokens": 210000,
        "unique_words": 9800,
        "top_words": {"и": 9500, "в": 7800, "не": 6200, "он": 4800, "что": 4500}
    },
    {
        "id": 3,
        "title": "Вишнёвый сад",
        "author": "Чехов А.П.",
        "year": 1904,
        "genre": "пьеса",
        "tokens": 45000,
        "unique_words": 4200,
        "top_words": {"и": 2100, "в": 1800, "не": 1200, "я": 950, "что": 880}
    },
    {
        "id": 4,
        "title": "Капитанская дочка",
        "author": "Пушкин А.С.",
        "year": 1836,
        "genre": "повесть",
        "tokens": 68000,
        "unique_words": 5600,
        "top_words": {"и": 3100, "в": 2700, "не": 1900, "я": 1400, "что": 1200}
    },
    {
        "id": 5,
        "title": "Мёртвые души",
        "author": "Гоголь Н.В.",
        "year": 1842,
        "genre": "поэма",
        "tokens": 95000,
        "unique_words": 7200,
        "top_words": {"и": 4200, "в": 3500, "не": 2800, "он": 2100, "что": 1900}
    },
    {
        "id": 6,
        "title": "Гроза",
        "author": "Островский А.Н.",
        "year": 1859,
        "genre": "пьеса",
        "tokens": 52000,
        "unique_words": 4800,
        "top_words": {"и": 2400, "в": 1900, "не": 1350, "я": 1100, "что": 980}
    }
]

# your code here

# %% [markdown]
# #### Задача 8 (**) - продолжение
#
# У нас есть два источника данных:
# - `corpus` — информация о текстах
# - `authors_info` — дополнительная информация об авторах
#
# Нужно объединить их по автору и добавить информацию о веке написания. Затем выводим поля в таком порядке: автор, название, год рождения автора, век написания.

# %%
# Дополнительная таблица с информацией об авторах
authors_info = [
    {"author": "Толстой Л.Н.", "birth_year": 1828, "death_year": 1910, "main_genre": "роман"},
    {"author": "Достоевский Ф.М.", "birth_year": 1821, "death_year": 1881, "main_genre": "роман"},
    {"author": "Чехов А.П.", "birth_year": 1860, "death_year": 1904, "main_genre": "пьеса"},
    {"author": "Пушкин А.С.", "birth_year": 1799, "death_year": 1837, "main_genre": "поэзия"},
    {"author": "Гоголь Н.В.", "birth_year": 1809, "death_year": 1852, "main_genre": "проза"},
    {"author": "Островский А.Н.", "birth_year": 1823, "death_year": 1886, "main_genre": "пьеса"},
]

# your code here
