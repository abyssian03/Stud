# %% [markdown]
# 1. Зададим словарь, в котором ключами будут выступать названия месяцев, а значениями - количество дней для каждого месяца.

# %%
lst = ["Jan", "Feb", "Mar", "Apr", "May", "Jun", "Jul", "Aug", "Sep", "Oct", "Nov", "Dec"]
lst2 = [31, 28, 31, 30, 31, 30, 31, 31, 30, 31, 30, 31]
dct = dict(zip(lst, lst2))
print(dct)
# my code here
# Out:
# {'Jan': 31, 'Feb': 28, 'Mar': 31, 'Apr': 30, 'May': 31, 'Jun': 30, 'Jul': 31, 'Aug': 31, 'Sep': 30, 'Oct': 31, 'Nov': 30, 'Dec': 31}

# %% [markdown]
# 2. Красиво выведем получившийся словарь в печать.

# %%
for key, val in dct.items():
    print(f"{key} - {val} days")
# my code here
# Out:
# Jan - 31 days
# Feb - 28 days
# Mar - 31 days
# Apr - 30 days
# May - 31 days
# Jun - 30 days
# Jul - 31 days
# Aug - 31 days
# Sep - 30 days
# Oct - 31 days
# Nov - 30 days
# Dec - 31 days

# %% [markdown]
# 3. Посмотрим отдельно ключи и отдельно значения нашего словаря.

# %%
for value in dct.values():
  print(value)
# my code here
# Out:
# 31
# 28
# 31
# 30
# 31
# 30
# 31
# 31
# 30
# 31
# 30
# 31

# %% [markdown]
# 4. Поменяем ключи и значения местами: теперь вместо ключей будет количество дней, а вместо значений - списки месяцев с таким количеством.

# %%
new_dct = {28: [], 30: [], 31: []}
for key, value in dct.items():
    new_dct[value].append(key)
print(new_dct)
# my code here
# Out:
# {28: ['Feb'], 30: ['Apr', 'Jun', 'Sep', 'Nov'], 31: ['Jan', 'Mar', 'May', 'Jul', 'Aug', 'Oct', 'Dec']}

# %% [markdown]
# 5. Заведем словарь с переводами каких-нибудь слов. Хотим добавить перевод для одного из слов, но таким образом, чтобы если там уже был какой-то вариант, он сохранился (н-р, было небо - sky, а мы хотим добавить вариант heaven).

# %%
translations = {"кошка": "cat", "небо" : "sky"}
translations["небо"] = [translations["небо"], "heaven"]
print(translations)
# my code here
# Out:
# {'кошка': 'cat', 'небо': ['sky', 'heaven']}

# %% [markdown]
# 6. Вводится текст. Нам нужно составить список частот встречающихся в нем слов. Как это сделать?

# %%
text = '... rrr ... fff ...'
lst = text.split()
dct = dict.fromkeys(lst, 0)
for word in lst:
    dct[word] = lst.count(word)
print(dct)
# my code here
# Out:
# {'...': 3, 'rrr': 1, 'fff': 1}
