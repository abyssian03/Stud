# %% [markdown]
# ####Задача 1.
#
# Дан словарь с числовыми значениями. Необходимо их все перемножить и вывести на экран.

# %%
# your code here

# %% [markdown]
# ####Задача 2.
#
# Даны два словаря частотности слов в некоторых текстах. Нужно объединить их так, чтобы при совпадении ключей-слов значения-частоты складывались.

# %%
# your code here

# %% [markdown]
# ####Задача 3.
#
# Делаем словарь синонимов. Пользователь вводит пары слов-синонимов. Напишите программу, которая по введенному слову возвращает его синоним (словарь работает в обе стороны).

# %%
# your code here

# %% [markdown]
# ####Задача 4.
#
# Вася на протяжении 5 рабочих дней недели каждый день ходил в продуктовый магазин и вел учет всех покупок, которые там делал. Также он каждый день вел учет своего потребления продуктов. Теперь он хочет проанализировать эти данные, чтобы понять, в какие из дней у него кончались определенные продукты, чтобы в следующий раз покупать их на это время больше. Помогите ему.
#
# Программа должна выводить название дня, а затем принимать на вход строки вида "хлеб +2" (означает, что куплено 2 батона хлеба) или "виноград -1" (означает, что съедена одна кисть винограда), пока не будет введено слово "все". Затем она должна записывать эти данные в словарь, в ключах которого записаны названия продуктов, а в значениях их количество, если оно положительное, и выводить содержимое словаря в виде "<продукт>: <количество>", каждую запись на отдельной строке. Если в каком-то из значений появилось отрицательное число, должна выводиться надпись "Ошибка значения, введите обновленные данные: сколько сейчас <продукта>"? И если введено неотрицательное число, должна обновлять соответствующую запись словаря, в ином случае повторять запрос, пока оно не будет введено. После этого программа должна проверять, какие из значений равны 0, и для каждого из них выводить надпись вида "Нет хлеба" или "Нет молока". После окончания вывода данных по текущему дню программа должна напечатать разделитель - четыре символа нижнего подчеркивания - и перейти к следующему дню.
#
# Полный список продуктов: йогурт, хлеб, сыр, шоколад, виноград, редис.
# Начальные данные - нулевое количество всех продуктов.
#
# **Пример**:
# *Вывод:* ПОНЕДЕЛЬНИК
#
# *Ввод:*
#
# йогурт +2
#
# хлеб +2
#
# виноград +3
#
# йогурт -1
#
# хлеб -1
#
# все
#
# *Вывод:* Сейчас имеется:
#
# йогурт: 1
#
# хлеб 1
#
# виноград: 3
#
# Нет сыра
#
# Нет шоколада
#
# Нет редиса
#
# \____
#
# *Вывод:* ВТОРНИК
#
# *Ввод:*
#
# сыр +1
#
# шоколад +3
#
# редис +5
#
# йогурт -1
#
# шоколад -1
#
# виноград -3
#
# все
#
# *Вывод*: Сейчас имеется:
#
# хлеб: 1
#
# сыр: 1
#
# шоколад: 2
#
# редис: 5
#
# Нет йогурта
#
# Нет винограда
#
# \____
#
# *Вывод:* СРЕДА
#
# *Ввод:*
#
# йогурт +2
#
# редис -5
#
# йогурт -1
#
# хлеб -1
#
# все
#
# *Вывод*: Сейчас имеется:
#
# йогурт: 1
#
# сыр: 1
#
# шоколад: 2
#
# Нет хлеба
#
# Нет винограда
#
# Нет редиса
#
# \____
#
# *Вывод:* ЧЕТВЕРГ
#
# *Ввод:*
#
# хлеб +1
#
# редис +5
#
# сыр -1
#
# шоколад -2
#
# все
#
# *Вывод*: Сейчас имеется:
#
# йогурт: 1
#
# хлеб: 1
#
# редис: 5
#
# Нет сыра
#
# Нет шоколада
#
# Нет винограда
#
# \____
#
# *Вывод:* ПЯТНИЦА
#
# *Ввод:*
#
# сыр +1
#
# хлеб +1
#
# шоколад +5
#
# хлеб -1
#
# йогурт -1
#
# редис -3
#
# все
#
# *Вывод*: Сейчас имеется:
#
# хлеб: 1
#
# сыр: 1
#
# шоколад: 5
#
# редис: 2
#
# Нет йогурта
#
# Нет винограда

# %%
# your code here

# %% [markdown]
# ####Задача 5.
#
# Пишем продвинутый справочник контактов. Создайте словарь, где ключ — имя, а значение — вложенный словарь с данными (телефон, email, адрес). Реализуйте функции добавления, удаления и поиска контактов.

# %%
# your code here

# %% [markdown]
# ####Задача 6.
#
# Делаем программу, которая принимает на вход слог русского языка (записанный кириллицей с употреблением спецсимволов при необходимости - напишите инструкцию для пользователя по способу записи и выведите ее на экран). В качестве результата программа выдает словарь разбора этого слога по признакам: количество букв в нем, открытость/закрытость, твердость/мягкость. При определении твердости и мягкости для простоты будем ориентироваться только на наличие мягкого знака или специального символа мягкости - апострофа.

# %%
# your code here

# %% [markdown]
# ####Задача 7 (*) - реальный лингвистический кейс
#
# В ячейке представлен автоматический морфологический разбор предложения. Изучите этот разбор. Посчитайте, сколько в нем словарей, выведите, какие у словарей есть ключи.
#
# Посчитайте, сколько в предложении слов.
#
# Попробуйте посчитать, сколько там глаголов и существительных (это можно сделать с помощью str.startswith() - метода строки, который проверяет, что строчка начинается на аргумент этого метода).
#
# Подумайте, что означают слова со значением ключа bastard?

# %%
analyze = [{'analysis': [{'lex': 'это', 'gr': 'SPRO,ед,сред,неод=(вин|им)'}], 'text': 'Это'}, {'text': ' '},
           {'analysis': [{'lex': 'быть', 'gr': 'V,нп=прош,ед,изъяв,сред,несов'}], 'text': 'было'}, {'text': ' '},
           {'analysis': [{'lex': 'у', 'gr': 'PR='}], 'text': 'у'}, {'text': ' '},
           {'analysis': [{'lex': 'место', 'gr': 'S,сред,неод=(вин,мн|род,ед|им,мн)'}], 'text': 'места'}, {'text': ', '},
           {'analysis': [{'lex': 'потому', 'gr': 'ADVPRO='}], 'text': 'потому'}, {'text': ' '},
           {'analysis': [{'lex': 'что', 'gr': 'CONJ='}], 'text': 'что'}, {'text': ' '},
           {'analysis': [{'lex': 'фемистоклюс', 'qual': 'bastard', 'gr': 'S,фам,муж,од=им,ед'}], 'text': 'Фемистоклюс'}, {'text': ' '},
           {'analysis': [{'lex': 'укусить', 'gr': 'V,сов,пе=прош,ед,изъяв,муж'}], 'text': 'укусил'}, {'text': ' '},
           {'analysis': [{'lex': 'за', 'gr': 'PR='}], 'text': 'за'}, {'text': ' '},
           {'analysis': [{'lex': 'ухо', 'gr': 'S,сред,неод=(вин,ед|им,ед)'}], 'text': 'ухо'}, {'text': ' '},
           {'analysis': [{'lex': 'алкид', 'qual': 'bastard', 'gr': 'S,муж,неод=род,ед'}], 'text': 'Алкида'}, {'text': ', '},
           {'analysis': [{'lex': 'и', 'gr': 'CONJ='}], 'text': 'и'}, {'text': ' '},
           {'analysis': [{'lex': 'алкид', 'qual': 'bastard', 'gr': 'S,муж,неод=(вин,ед|им,ед)'}], 'text': 'Алкид'}, {'text': ', '},
           {'analysis': [{'lex': 'зажмуривать', 'gr': 'V,пе=прош,деепр,сов'}], 'text': 'зажмурив'}, {'text': ' '},
           {'analysis': [{'lex': 'глаз', 'gr': 'S,муж,неод=(вин,мн|род,ед|им,мн)'}], 'text': 'глаза'}, {'text': ' '},
           {'analysis': [{'lex': 'и', 'gr': 'CONJ='}], 'text': 'и'}, {'text': ' '},
           {'analysis': [{'lex': 'открывать', 'gr': 'V=прош,деепр,сов'}], 'text': 'открыв'}, {'text': ' '},
           {'analysis': [{'lex': 'рот', 'gr': 'S,муж,неод=(вин,ед|им,ед)'}], 'text': 'рот'}, {'text': ', '},
           {'analysis': [{'lex': 'готовый', 'gr': 'A=ед,кр,муж'}], 'text': 'готов'}, {'text': ' '},
           {'analysis': [{'lex': 'быть', 'gr': 'V,нп=прош,ед,изъяв,муж,несов'}], 'text': 'был'}, {'text': ' '},
           {'analysis': [{'lex': 'зарыдать', 'gr': 'V,сов,нп=инф'}], 'text': 'зарыдать'}, {'text': ' '},
           {'analysis': [{'lex': 'самый', 'gr': 'APRO=(дат,мн|твор,ед,муж|твор,ед,сред)'}], 'text': 'самым'}, {'text': ' '},
           {'analysis': [{'lex': 'жалкий', 'gr': 'A=(дат,мн,полн|твор,ед,полн,муж|твор,ед,полн,сред)'}], 'text': 'жалким'}, {'text': ' '},
           {'analysis': [{'lex': 'образ', 'gr': 'S,муж,неод=твор,ед'}], 'text': 'образом'}, {'text': ', '},
           {'analysis': [{'lex': 'но', 'gr': 'CONJ='}], 'text': 'но'}, {'text': ', '}, {'analysis': [{'lex': 'почувствовать', 'gr': 'V,сов,пе=прош,деепр'}], 'text': 'почувствовав'}, {'text': ', '},
           {'analysis': [{'lex': 'что', 'gr': 'CONJ='}], 'text': 'что'}, {'text': ' '},
           {'analysis': [{'lex': 'за', 'gr': 'PR='}], 'text': 'за'}, {'text': ' '},
           {'analysis': [{'lex': 'это', 'gr': 'SPRO,ед,сред,неод=(вин|им)'}], 'text': 'это'}, {'text': ' '},
           {'analysis': [{'lex': 'легко', 'gr': 'ADV='}], 'text': 'легко'}, {'text': ' '},
           {'analysis': [{'lex': 'можно', 'gr': 'ADV,прдк='}], 'text': 'можно'}, {'text': ' '},
           {'analysis': [{'lex': 'быть', 'gr': 'V,нп=прош,ед,изъяв,сред,несов'}], 'text': 'было'}, {'text': ' '},
           {'analysis': [{'lex': 'лишаться', 'gr': 'V,нп=инф,сов'}], 'text': 'лишиться'}, {'text': ' '},
           {'analysis': [{'lex': 'блюдо', 'gr': 'S,сред,неод=(вин,мн|род,ед|им,мн)'}], 'text': 'блюда'}, {'text': ', '},
           {'analysis': [{'lex': 'приводить', 'gr': 'V=прош,ед,изъяв,муж,сов'}], 'text': 'привел'}, {'text': ' '},
           {'analysis': [{'lex': 'рот', 'gr': 'S,муж,неод=(вин,ед|им,ед)'}], 'text': 'рот'}, {'text': ' '},
           {'analysis': [{'lex': 'в', 'gr': 'PR='}], 'text': 'в'}, {'text': ' '},
           {'analysis': [{'lex': 'прежний', 'gr': 'A=(вин,ед,полн,сред|им,ед,полн,сред)'}], 'text': 'прежнее'}, {'text': ' '},
           {'analysis': [{'lex': 'положение', 'gr': 'S,сред,неод=(вин,ед|им,ед)'}], 'text': 'положение'}, {'text': ' '},
           {'analysis': [{'lex': 'и', 'gr': 'CONJ='}], 'text': 'и'}, {'text': ' '},
           {'analysis': [{'lex': 'начинать', 'gr': 'V,пе=прош,ед,изъяв,муж,сов'}], 'text': 'начал'}, {'text': ' '},
           {'analysis': [{'lex': 'со', 'gr': 'PR='}], 'text': 'со'}, {'text': ' '},
           {'analysis': [{'lex': 'слеза', 'gr': 'S,жен,неод=твор,мн'}], 'text': 'слезами'}, {'text': ' '},
           {'analysis': [{'lex': 'грызть', 'gr': 'V,несов,пе=инф'}], 'text': 'грызть'}, {'text': ' '},
           {'analysis': [{'lex': 'бараний', 'gr': 'A,полн=вин,ед,жен'}], 'text': 'баранью'}, {'text': ' '},
           {'analysis': [{'lex': 'кость', 'gr': 'S,жен,неод=(вин,ед|им,ед)'}], 'text': 'кость'}, {'text': ', '},
           {'analysis': [{'lex': 'от', 'gr': 'PR='}], 'text': 'от'}, {'text': ' '},
           {'analysis': [{'lex': 'который', 'gr': 'APRO=(пр,ед,жен|дат,ед,жен|род,ед,жен|твор,ед,жен)'}], 'text': 'которой'}, {'text': ' '},
           {'analysis': [{'lex': 'у', 'gr': 'PR='}], 'text': 'у'}, {'text': ' '},
           {'analysis': [{'lex': 'он', 'gr': 'SPRO,ед,3-л,муж=(вин|род)'}], 'text': 'него'}, {'text': ' '},
           {'analysis': [{'lex': 'оба', 'gr': 'NUM=(им,жен|вин,жен,неод)'}], 'text': 'обе'}, {'text': ' '},
           {'analysis': [{'lex': 'щека', 'gr': 'S,жен,неод=(вин,мн|род,ед|им,мн)'}], 'text': 'щеки'}, {'text': ' '},
           {'analysis': [{'lex': 'лосниться', 'gr': 'V,несов,нп=прош,мн,изъяв'}], 'text': 'лоснились'}, {'text': ' '},
           {'analysis': [{'lex': 'жир', 'gr': 'S,муж,неод=твор,ед'}], 'text': 'жиром'}, {'text': '.'}, {'text': '\n'}]

# your code here
